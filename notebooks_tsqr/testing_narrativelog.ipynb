# %%
# import narrativelog adapter
from lsst.ts.logging_and_reporting.all_sources import AllSources

# call it
# inspect the data that comes in
# can we sort it based on time loss?

# %%
AllSources.__dict__
